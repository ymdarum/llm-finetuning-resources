# %% [markdown]
# # Llama.cpp python inference
# https://llama-cpp-python.readthedocs.io/en/latest/

# %% [markdown]
# Inference over our trained ascii adapters

# %%
from llama_cpp import Llama

# %%
llm = Llama(
      model_path="/Users/woutvossen/Documents/programming/llm-finetuning-resources/models/pg.gguf",
)
# Out:
# llama_model_load_from_file_impl: using device Metal (Apple M1 Pro) - 10916 MiB free
# llama_model_loader: loaded meta data with 31 key-value pairs and 292 tensors from /Users/woutvossen/Documents/programming/llm-finetuning-resources/models/pg.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Meta Llama 3.1 8b Instruct Bnb 4bit
# llama_model_loader: - kv   3:                       general.organization str              = Unsloth
# llama_model_loader: - kv   4:                           general.finetune str              = instruct-bnb-4bit
# ...

# %%
llm.create_chat_completion(
      messages = [
        {"role": "user", "content": "Who are you?"},
      ]
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 llm.create_chat_completion(
#       2       messages = [
#       3     {"role": "user", "content": "Who are you?"},
#       4
#       5       ],verbose=True
#       6 )
#
# TypeError: Llama.create_chat_completion() got an unexpected keyword argument 'verbose'

# %%
print(llm.chat_format)  # This might return "llama-2", "mistral", "chatml", or something else.
# Out:
# chat_template.default
